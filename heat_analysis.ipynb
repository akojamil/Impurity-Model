# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('ggplot')

# %% [markdown]
# # Center Line of Teflon Circle

# %%
data = pd.read_csv("setup4center_clean.csv")
data.head()
# Out:
#           x           0           1           2           3           4  \
# 0  0.009375  292.920990  300.743630  301.669913  302.015727  302.180704
# 1  0.028125  293.254650  297.685777  299.331579  300.084722  300.494938
# 2  0.046875  293.065226  295.659095  297.408974  298.366876  298.951842
# 3  0.065625  293.150397  294.509338  296.003850  296.973199  297.638510
# 4  0.084375  293.160778  293.824819  294.997737  295.884760  296.559908
#
#             5           6           7           8  ...        3591  \
# 0  302.323588  302.377560  302.431531  302.485503  ...  303.150000
# 1  300.852419  300.997658  301.142897  301.288136  ...  303.149999
# 2  299.465060  299.689503  299.913947  300.138390  ...  303.149998
# 3  298.227711  298.510583  298.793455  299.076327  ...  303.149997
# 4  297.164250  297.483615  297.802979  298.122344  ...  303.149997
#
#          3592        3593        3594        3595        3596        3597  \
# ...

# %%
# Timescale in seconds on which to view the data. 3601 is full-length
TSCALE = 3601
# temperatures only
temp_data = data.drop("x", axis=1).transpose()[0:TSCALE]

# %%
temp_data.head()
# Out:
#            0           1           2           3           4           5   \
# 0  292.920990  293.254650  293.065226  293.150397  293.160778  293.145313
# 1  300.743630  297.685777  295.659095  294.509338  293.824819  293.522512
# 2  301.669913  299.331579  297.408974  296.003850  294.997737  294.355622
# 3  302.015727  300.084722  298.366876  296.973199  295.884760  295.090187
# 4  302.180704  300.494938  298.951842  297.638510  296.559908  295.712917
#
#            6           7           8           9   ...          30  \
# 0  293.152119  293.148290  293.150005  293.150217  ...  293.150000
# 1  293.331739  293.245298  293.199050  293.173000  ...  293.150000
# 2  293.907340  293.631180  293.453690  293.335909  ...  293.150028
# 3  294.497019  294.085812  293.797227  293.590723  ...  293.150609
# 4  295.046842  294.547906  294.174022  293.891173  ...  293.151674
#
#            31          32          33          34          35          36  \
# ...

# %%
# Median temperatures
median_temps = temp_data.median(axis=1)
#median_temps.shape
# Minimum temperatures
min_temps = temp_data.min(axis=1)
max_temps = temp_data.max(axis=1)

# %%
#median_temps.head()

# %%
fig, ax = plt.subplots(figsize=(10,6))
plt.plot(np.arange(TSCALE), max_temps, label="Maximum")
plt.plot(np.arange(TSCALE), median_temps, label="Median")
plt.plot(np.arange(TSCALE), min_temps, label="Minimum")
plt.title("Temperature over Time")
plt.legend(loc=4)
plt.show()

# %%
max_temps.to_csv("setup4max.csv")
median_temps.to_csv("setup4med.csv")
min_temps.to_csv("setup4min.csv")
